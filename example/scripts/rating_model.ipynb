# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Rating models

# %%
import matplotlib.pyplot as plt

from movie_ratings import config
from taskchain.task import MultiChain

# %%
chains = MultiChain.from_dir(config.TASKS_DIR, config.CONFIGS_DIR / 'rating_model/all_movies', global_vars=config)
print(chains)
chain = chains.latest('nn')
# Out:
# linear_regression
# nn
# tf_linear_regression

# %%
chain.test_metrics.value
# Out:
# INFO:task_rating_model:test_metrics:rating_model:test_metrics - run started with params: None
# INFO:task_rating_model:trained_model:rating_model:trained_model - run started with params: model=NeuralRatingModel(dropout=0.8, layers=[50, 10], learning_params={'epochs': 10, 'lr_schedule': [[1, 0.001], [5, 0.0001], [8, 1e-05], [10, 1e-06]]})
# INFO:task_rating_model:train_model:rating_model:train_model - run started with params: model=NeuralRatingModel(dropout=0.8, layers=[50, 10], learning_params={'epochs': 10, 'lr_schedule': [[1, 0.001], [5, 0.0001], [8, 1e-05], [10, 1e-06]]})
# Epoch 1/10
# 838/838 [==============================] - 2s 2ms/step - loss: 1.8328 - root_mean_squared_error: 1.3538
# Epoch 2/10
# 838/838 [==============================] - 2s 2ms/step - loss: 1.1280 - root_mean_squared_error: 1.0621
# Epoch 3/10
# 838/838 [==============================] - 2s 2ms/step - loss: 1.0576 - root_mean_squared_error: 1.0284
# Epoch 4/10
# 838/838 [==============================] - 2s 2ms/step - loss: 1.0362 - root_mean_squared_error: 1.0179
# Epoch 5/10
# 838/838 [==============================] - 2s 2ms/step - loss: 1.0172 - root_mean_squared_error: 1.0086
# Epoch 6/10
# 838/838 [==============================] - 2s 2ms/step - loss: 1.0112 - root_mean_squared_error: 1.0056
# Epoch 7/10
# 838/838 [==============================] - 2s 2ms/step - loss: 0.9968 - root_mean_squared_error: 0.9984
# Epoch 8/10
# 838/838 [==============================] - 2s 2ms/step - loss: 0.9940 - root_mean_squared_error: 0.9970
# Epoch 9/10
# 838/838 [==============================] - 2s 2ms/step - loss: 0.9935 - root_mean_squared_error: 0.9967
# Epoch 10/10
# 838/838 [==============================] - 2s 2ms/step - loss: 0.9985 - root_mean_squared_error: 0.9992
# INFO:tensorflow:Assets written to: /home/thran/projects/taskchain/example/data/task_data/rating_model/train_model/6a2fd5980ebc2180a0bf2b390f05feb9_tmp/assets
# INFO:tensorflow:Assets written to: /home/thran/projects/taskchain/example/data/task_data/rating_model/train_model/6a2fd5980ebc2180a0bf2b390f05feb9_tmp/assets
# INFO:task_rating_model:train_model:rating_model:train_model - run ended
# WARNING:absl:Importing a function (__inference_dense_16_layer_call_and_return_conditional_losses_137983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_6_layer_call_and_return_conditional_losses_138527) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_137760) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_6_layer_call_and_return_conditional_losses_138443) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_dense_15_layer_call_and_return_conditional_losses_138623) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_dense_15_layer_call_and_return_conditional_losses_137954) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_dense_16_layer_call_and_return_conditional_losses_138675) with ops with custom gradients. Will likely fail if a gradient is requested.
# INFO:task_rating_model:trained_model:rating_model:trained_model - run ended
# INFO:task_rating_model:test_metrics:rating_model:test_metrics - run ended
# {'RMSE': 0.9526817254430104, 'MAE': 0.7247280220542708}

# %%
for name, chain in chains.items():
    print(f'{name:>20}: {chain.test_metrics.value["RMSE"]:.3f}')
# Out:
#    linear_regression: 0.931
#                   nn: 0.953
# tf_linear_regression: 0.914
