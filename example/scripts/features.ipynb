# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Features

# %%
import matplotlib.pyplot as plt

from movie_ratings import config
from taskchain import Config

# %%
config_name = 'features/all.yaml'
chain = Config(config.TASKS_DIR, config.CONFIGS_DIR / config_name, global_vars=config).chain()
print(chain)
# Out:
# all_movies          movies:all_movies            imdb.filtered/movies:all_movies
# movies              movies:movies                imdb.filtered/movies:movies
# directors           movies:directors             imdb.filtered/movies:directors
# selected_directors  features:selected_directors  all/features:selected_directors
# actors              movies:actors                imdb.filtered/movies:actors
# selected_actors     features:selected_actors     all/features:selected_actors
# genres              movies:genres                imdb.filtered/movies:genres
# countries           movies:countries             imdb.filtered/movies:countries
# all_features        features:all_features        all/features:all_features
# feature_names       features:feature_names       all/features:feature_names
# features            features:features            all/features:features
# movie_names         movies:movie_names           imdb.filtered/movies:movie_names
# duration_histogram  movies:duration_histogram    imdb.filtered/movies:duration_histogram
# year_histogram      movies:year_histogram        imdb.filtered/movies:year_histogram

# %%
chain.draw()
# Out:
# Warning: using box for unknown shape plain_text

# %% [markdown]
# ## Directors

# %%
len(chain.directors.value)
# Out:
# 12263

# %%
len(chain.selected_directors.value)
# Out:
# 411

# %% [markdown]
# ## Actors

# %%
len(chain.actors.value)
# Out:
# 173183

# %%
chain.all_features.value.shape
# Out:
# 1713

# %% [markdown]
# ## Features

# %%
len(chain.selected_actors.value)
# Out:
# (28215, 2029)

# %%
len(chain.feature_names.value)
# Out:
# 2029

# %%
chain.features.value.shape
# Out:
# (28215, 2029)

# %%
# Out:
# {'tt0035423': 'Kate & Leopold',
#  'tt0036868': 'The Best Years of Our Lives',
#  'tt0037492': 'Bud Abbott and Lou Costello in Hollywood',
#  'tt0037508': 'Along Came Jones',
#  'tt0037514': 'Anchors Aweigh',
#  'tt0037515': 'And Then There Were None',
#  'tt0037522': 'Back to Bataan',
#  'tt0037536': "The Bells of St. Mary's",
#  'tt0037547': 'Blood on the Sun',
#  'tt0037549': 'The Body Snatcher',
#  'tt0037557': "Brewster's Millions",
#  'tt0037558': 'Brief Encounter',
#  'tt0037563': 'The Bullfighters',
#  'tt0037576': 'Captain Kidd',
#  'tt0037604': 'The Clock',
#  'tt0037611': 'Conflict',
#  'tt0037614': 'The Corn Is Green',
#  'tt0037627': 'Dakota',
#  'tt0037630': 'Les dames du Bois de Boulogne',
#  'tt0037635': 'Dead of Night',
#  'tt0037638': 'Detour',
#  'tt0037642': 'Dick Tracy',
#  'tt0037644': 'Dillinger',
#  'tt0037671': 'The Enchanted Cottage',
#  'tt0037674': 'Les enfants du paradis',
#  'tt0037691': 'Fallen Angel',
#  'tt0037702': 'Flame of Barbary Coast',
#  'tt0037749': 'The Great Flamarion',
#  'tt0037761': 'Hangover Square',
#  'tt0037771': 'Here Come the Co-eds',
#  'tt0037790': 'The Horn Blows at Midnight',
#  'tt0037793': 'House of Dracula',
#  'tt0037794': 'The House of Fear',
#  'tt0037795': 'The House on 92nd Street',
#  'tt0037800': "I Know Where I'm Going!",
#  'tt0037820': 'Isle of the Dead',
#  'tt0037826': 'The Jade Mask',
#  'tt0037859': 'Lady on a Train',
#  'tt0037865': 'Leave Her to Heaven',
#  'tt0037884': 'The Lost Weekend',
#  'tt0037885': 'Love Letters',
#  'tt0037913': 'Mildred Pierce',
#  'tt0037931': 'Murder, He Says',
#  'tt0037932': 'My Name Is Julia Ross',
#  'tt0037939': 'The Naughty Nineties',
#  'tt0037954': 'Objective, Burma!',
#  'tt0037963': 'Our Vines Have Tender Grapes',
#  'tt0037980': 'Perfect Strangers',
#  'tt0037988': 'The Picture of Dorian Gray',
#  'tt0038000': 'Pride of the Marines',
#  'tt0038008': 'Pursuit to Algiers',
#  'tt0038026': 'Rhapsody in Blue',
#  'tt0038032': 'Road to Utopia',
#  'tt0038048': 'San Antonio',
#  'tt0038053': 'Saratoga Trunk',
#  'tt0038056': 'The Scarlet Clue',
#  'tt0038057': 'Scarlet Street',
#  'tt0038080': 'The Shanghai Cobra',
#  'tt0038104': 'A Song to Remember',
#  'tt0038107': 'The Southerner',
#  'tt0038108': 'The Spanish Main',
#  'tt0038109': 'Spellbound',
#  'tt0038116': 'State Fair',
#  'tt0038120': 'Story of G.I. Joe',
#  'tt0038123': 'The Strange Affair of Uncle Harry',
#  'tt0038151': 'Tarzan and the Amazons',
#  'tt0038182': 'Tora no o wo fumu otokotachi',
#  'tt0038190': 'A Tree Grows in Brooklyn',
#  'tt0038213': 'The Valley of Decision',
#  'tt0038235': 'A Walk in the Sun',
#  'tt0038238': 'The Way to the Stars',
#  'tt0038239': 'Week-End at the Waldorf',
#  'tt0038250': 'The Wicked Lady',
#  'tt0038256': 'Without Love',
#  'tt0038259': 'The Woman in Green',
#  'tt0038260': 'Wonder Man',
#  'tt0038268': 'Zoku Sugata Sanshirô',
#  'tt0038279': '13 Rue Madeleine',
#  'tt0038289': 'I See a Dark Stranger',
#  'tt0038300': 'Angel on My Shoulder',
#  'tt0038303': 'Anna and the King of Siam',
#  'tt0038338': 'The Beast with Five Fingers',
#  'tt0038343': 'Bedlam',
#  'tt0038348': 'La belle et la bête',
#  'tt0038355': 'The Big Sleep',
#  'tt0038360': 'Black Angel',
#  'tt0038363': 'Blithe Spirit',
#  'tt0038370': 'Blue Skies',
#  'tt0038387': 'The Brute Man',
#  'tt0038390': 'Caesar and Cleopatra',
#  'tt0038395': 'Canyon Passage',
#  'tt0038409': 'The Chase',
#  'tt0038417': 'Cloak and Dagger',
#  'tt0038419': 'Cluny Brown',
#  'tt0038427': 'Courage of Lassie',
#  'tt0038429': 'Crack-Up',
#  'tt0038449': 'Dangerous Money',
#  'tt0038452': 'Dark Alibi',
#  'tt0038453': 'The Dark Corner',
#  'tt0038455': 'The Dark Mirror',
#  'tt0038458': 'Deadline at Dawn',
#  'tt0038461': 'Deception',
#  'tt0038462': 'Decoy',
#  'tt0038468': 'Det regnar på vår kärlek',
#  'tt0038477': 'The Diary of a Chambermaid',
#  'tt0038478': 'Dick Tracy vs. Cueball',
#  'tt0038492': 'Dragonwyck',
#  'tt0038494': 'Dressed to Kill',
#  'tt0038499': 'Duel in the Sun',
#  'tt0038559': 'Gilda',
#  'tt0038574': 'Great Expectations',
#  'tt0038577': 'Green for Danger',
#  'tt0038589': 'The Harvey Girls',
#  'tt0038622': 'Humoresque',
#  'tt0038650': "It's a Wonderful Life",
#  'tt0038661': 'The Jolson Story',
#  'tt0038669': 'The Killers',
#  'tt0038675': 'Kris',
#  'tt0038694': 'Little Giant',
#  'tt0038700': 'The Locket',
#  'tt0038718': 'Make Mine Music',
#  'tt0038733': 'A Matter of Life and Death',
#  'tt0038762': 'My Darling Clementine',
#  'tt0038765': 'My Reputation',
#  'tt0038776': 'Night and Day',
#  'tt0038777': 'A Night in Casablanca',
#  'tt0038780': 'Nobody Lives Forever',
#  'tt0038782': 'Nocturne',
#  'tt0038787': 'Notorious',
#  'tt0038824': 'Panique',
#  'tt0038853': 'Les portes de la nuit',
#  'tt0038854': 'The Postman Always Rings Twice',
#  'tt0038873': "The Razor's Edge",
#  'tt0038890': 'Roma città aperta',
#  'tt0038913': 'Sciuscià',
#  'tt0038924': 'The Seventh Veil',
#  'tt0038934': 'She-Wolf of London',
#  'tt0038937': 'Shock',
#  'tt0038958': 'So Dark the Night',
#  'tt0038965': 'Somewhere in the Night',
#  'tt0038969': 'Song of the South',
#  'tt0038975': 'The Spiral Staircase',
#  'tt0038984': 'A Stolen Life',
#  'tt0038988': 'The Strange Love of Martha Ivers',
#  'tt0038990': 'The Strange Woman',
#  'tt0038991': 'The Stranger',
#  'tt0039011': 'Tarzan and the Leopard Woman',
#  'tt0039017': 'Terror by Night',
#  'tt0039029': 'Three Strangers',
#  'tt0039036': 'Till the End of Time',
#  'tt0039037': 'The Time of Their Lives',
#  'tt0039040': 'To Each His Own',
#  'tt0039041': 'Tomorrow Is Forever',
#  'tt0039066': 'Undercurrent',
#  'tt0039074': 'Utamaro o meguru gonin no onna',
#  'tt0039080': 'The Verdict',
#  'tt0039090': 'Waga seishun ni kuinashi',
#  'tt0039110': 'Without Reservations',
#  'tt0039111': 'The Yearling',
#  'tt0039116': 'Ziegfeld Follies',
#  'tt0039152': 'Angel and the Badman',
#  'tt0039169': 'The Bachelor and the Bobby-Soxer',
#  'tt0039190': "The Bishop's Wife",
#  'tt0039192': 'Black Narcissus',
#  'tt0039204': 'Body and Soul',
#  'tt0039208': 'Boomerang!',
#  'tt0039211': 'Born to Kill',
#  'tt0039220': 'Brighton Rock',
#  'tt0039224': 'Brute Force',
#  'tt0039226': 'Buck Privates Come Home',
#  'tt0039243': 'Captain from Castile',
#  'tt0039277': 'Copacabana',
#  'tt0039288': 'Cry Wolf',
#  'tt0039302': 'Dark Passage',
#  'tt0039305': 'Dead Reckoning',
#  'tt0039311': 'Desert Fury',
#  'tt0039313': 'Desperate',
#  'tt0039320': 'Dick Tracy Meets Gruesome',
#  'tt0039324': 'Dishonored Lady',
#  'tt0039335': 'A Double Life',
#  'tt0039337': 'Down to Earth',
#  'tt0039349': 'The Egg and I',
#  'tt0039370': "The Farmer's Daughter",
#  'tt0039372': 'Fear in the Night',
#  'tt0039391': 'Forever Amber',
#  'tt0039396': 'Framed',
#  'tt0039402': 'The Fugitive',
#  'tt0039404': 'Fun & Fancy Free',
#  'tt0039416': "Gentleman's Agreement",
#  'tt0039417': 'Germania anno zero',
#  'tt0039420': 'The Ghost and Mrs. Muir',
#  'tt0039431': 'Good News',
#  'tt0039437': 'Green Dolphin Street',
#  'tt0039464': 'High Wall',
#  'tt0039477': 'The Hucksters',
#  'tt0039478': 'Hue and Cry',
#  'tt0039482': 'I Walk Alone',
#  'tt0039502': 'It Happened on Fifth Avenue',
#  'tt0039515': "Johnny O'Clock",
#  'tt0039545': 'Lady in the Lake',
#  'tt0039563': 'O Leão da Estrela',
#  'tt0039566': 'Life with Father',
#  'tt0039581': 'The Long Night',
#  'tt0039589': 'Lured',
#  'tt0039595': 'Magic Town',
#  'tt0039628': 'Miracle on 34th Street',
#  'tt0039631': 'Monsieur Verdoux',
#  'tt0039645': 'My Favorite Brunette',
#  'tt0039651': 'Nagaya shinshiroku',
#  'tt0039666': 'Nora Prentiss',
#  'tt0039676': 'The October Man',
#  'tt0039677': 'Odd Man Out',
#  'tt0039689': 'Out of the Past',
#  'tt0039694': 'The Paradine Case',
#  'tt0039698': 'The Perils of Pauline',
#  'tt0039725': 'Possessed',
#  'tt0039737': 'Pursued',
#  'tt0039739': 'Quai des Orfèvres',
#  'tt0039748': 'Railroaded!',
#  'tt0039750': 'Ramrod',
#  'tt0039757': 'The Red House',
#  'tt0039768': 'Ride the Pink Horse',
#  'tt0039776': 'Road to Rio',
#  'tt0039800': 'Scared to Death',
#  'tt0039806': 'The Sea of Grass',
#  'tt0039808': 'The Secret Life of Walter Mitty',
#  'tt0039822': 'Le silence de la mer',
#  'tt0039825': 'The Sin of Harold Diddlebock',
#  'tt0039826': 'Sinbad, the Sailor',
#  'tt0039834': 'Skepp till India land',
#  'tt0039840': 'Smash-Up: The Story of a Woman',
#  'tt0039853': 'Song of the Thin Man',
#  'tt0039871': 'Subarashiki nichiyôbi',
#  'tt0039881': 'T-Men',
#  'tt0039887': 'Tarzan and the Huntress',
#  'tt0039895': 'They Made Me a Fugitive',
#  'tt0039896': "They Won't Believe Me",
#  'tt0039926': 'The Two Mrs. Carrolls',
#  'tt0039927': 'Tycoon',
#  'tt0039941': 'The Unsuspected',
#  'tt0039998': 'The Wistful Widow of Wagon Gap',
#  'tt0040000': 'The Woman on the Beach',
#  'tt0040064': '3 Godfathers',
#  'tt0040068': 'Bud Abbott Lou Costello Meet Frankenstein',
#  'tt0040076': 'Adventures of Don Juan',
#  'tt0040087': 'All My Sons',
#  'tt0040092': "L'amore",
#  'tt0040098': 'Anna Karenina',
#  'tt0040109': 'Arch of Triumph',
#  'tt0040155': 'Berlin Express',
#  'tt0040160': 'The Big Clock',
#  'tt0040175': 'Blood on the Moon',
#  'tt0040185': 'The Boy with Green Hair',
#  'tt0040202': 'Call Northside 777',
#  'tt0040221': 'Caught',
#  'tt0040242': 'Command Decision',
#  'tt0040257': 'Cry of the City',
#  'tt0040270': 'The Dark Past',
#  'tt0040271': 'A Date with Judy',
#  'tt0040308': 'Easter Parade',
#  'tt0040317': 'The Emperor Waltz',
#  'tt0040338': 'The Fallen Idol',
#  'tt0040366': 'Force of Evil',
#  'tt0040367': 'A Foreign Affair',
#  'tt0040369': 'Fort Apache',
#  'tt0040416': 'Hamlet',
#  'tt0040418': 'Hamnstad',
#  'tt0040427': 'He Walked by Night',
#  'tt0040444': 'Hollow Triumph',
#  'tt0040458': 'I Remember Mama',
#  'tt0040481': 'It Always Rains on Sunday',
#  'tt0040491': 'Joan of Arc',
#  'tt0040495': 'Johnny Belinda',
#  'tt0040499': 'June Bride',
#  'tt0040505': 'Kaze no naka no mendori',
#  'tt0040506': 'Key Largo',
#  'tt0040522': 'Ladri di biciclette',
#  'tt0040525': 'The Lady from Shanghai',
#  'tt0040536': 'Letter from an Unknown Woman',
#  'tt0040550': 'Louisiana Story',
#  'tt0040558': 'Macbeth',
#  'tt0040580': 'Melody Time',
#  'tt0040582': 'Mexican Hayride',
#  'tt0040613': 'Mr. Blandings Builds His Dream House',
#  'tt0040614': 'Mr. Peabody and the Mermaid',
#  'tt0040622': 'Musik i mörker',
#  'tt0040636': 'The Naked City',
#  'tt0040643': 'Night Has a Thousand Eyes',
#  'tt0040662': 'Oliver Twist',
#  'tt0040669': 'One Touch of Venus',
#  'tt0040679': 'The Paleface',
#  'tt0040694': 'The Pirate',
#  'tt0040695': 'Pitfall',
#  'tt0040705': 'Portrait of Jennie',
#  'tt0040720': 'Rachel and the Stranger',
#  'tt0040723': 'Raw Deal',
#  'tt0040724': 'Red River',
#  'tt0040725': 'The Red Shoes',
#  'tt0040737': 'Riso amaro',
#  'tt0040740': 'Road House',
#  'tt0040745': 'Romance on the High Seas',
#  'tt0040746': 'Rope',
#  'tt0040751': 'Ruthless',
#  'tt0040761': 'Scott of the Antarctic',
#  'tt0040765': 'The Search',
#  'tt0040766': 'Secret Beyond the Door...',
#  'tt0040789': 'Silver River',
#  'tt0040798': 'Sleep, My Love',
#  'tt0040806': 'The Snake Pit',
#  'tt0040820': 'A Song Is Born',
#  'tt0040823': 'Sorry, Wrong Number',
#  'tt0040829': 'The Amazing Mr. X',
#  'tt0040834': 'State of the Union',
#  'tt0040843': 'The Street with No Name',
#  'tt0040862': 'Tarzan and the Mermaids',
#  'tt0040866': 'La terra trema',
#  'tt0040872': 'They Live by Night',
#  'tt0040876': 'The Three Musketeers',
#  'tt0040884': 'The Time of Your Life',
#  'tt0040897': 'The Treasure of the Sierra Madre',
#  'tt0040919': 'Unfaithfully Yours',
#  'tt0040946': 'Wake of the Red Witch',
#  'tt0040965': 'Whispering Smith',
#  'tt0040970': 'The Winslow Boy',
#  'tt0040971': 'Winter Meeting',
#  'tt0040974': 'The Woman in White',
#  'tt0040976': 'Words and Music',
#  'tt0040978': 'Yellow Sky',
#  'tt0040979': 'Yoidore tenshi',
#  'tt0040980': 'Yoru no onnatachi',
#  'tt0041085': 'Bud Abbott Lou Costello Meet the Killer Boris Karloff',
#  'tt0041088': 'Act of Violence',
#  'tt0041090': "Adam's Rib",
#  'tt0041094': 'The Adventures of Ichabod and Mr. Toad',
#  'tt0041098': 'Africa Screams',
#  'tt0041113': "All the King's Men",
#  'tt0041154': 'Banshun',
#  'tt0041158': 'The Barkleys of Broadway',
#  'tt0041162': 'Batman and Robin',
#  'tt0041163': 'Battleground',
#  'tt0041172': 'Beyond the Forest',
#  'tt0041178': 'The Big Steal',
#  'tt0041198': 'Border Incident',
#  'tt0041207': 'The Bribe',
#  'tt0041239': 'Champion',
#  'tt0041253': 'Colorado Territory',
#  'tt0041257': 'Come to the Stable',
#  'tt0041259': "A Connecticut Yankee in King Arthur's Court",
#  'tt0041327': 'East Side, West Side',
#  'tt0041329': 'Edward, My Son',
#  'tt0041361': 'The Fighting Kentuckian',
#  'tt0041368': 'The File on Thelma Jordon',
#  'tt0041373': 'Flamingo Road',
#  'tt0041378': 'Follow Me Quietly',
#  'tt0041386': 'The Fountainhead',
#  'tt0041387': 'Francis',
#  'tt0041399': 'Fängelse',
#  'tt0041423': 'El gran calavera',
#  'tt0041430': 'The Great Sinner',
#  'tt0041445': 'The Hasty Heart',
#  'tt0041452': 'The Heiress',
#  'tt0041460': 'Obsession',
#  'tt0041473': 'Holiday Affair',
#  'tt0041487': 'House of Strangers',
#  'tt0041497': 'I Shot Jesse James',
#  'tt0041503': 'Impact',
#  'tt0041507': 'In the Good Old Summertime',
#  'tt0041509': 'The Inspector General',
#  'tt0041513': 'Intruder in the Dust',
#  'tt0041514': 'It Happens Every Spring',
#  'tt0041515': "It's a Great Feeling",
#  'tt0041546': 'Kind Hearts and Coronets',
#  'tt0041555': 'Knock on Any Door',
#  'tt0041587': 'A Letter to Three Wives',
#  'tt0041594': 'Little Women',
#  'tt0041604': 'Love Happy',
#  'tt0041610': 'Lust for Gold',
#  'tt0041613': 'Ma and Pa Kettle',
#  'tt0041615': 'Madame Bovary',
#  'tt0041622': 'Malaya',
#  'tt0041625': 'The Man from Colorado',
#  'tt0041650': 'Mighty Joe Young',
#  'tt0041671': 'My Dream Is Yours',
#  'tt0041687': "Neptune's Daughter",
#  'tt0041694': 'No Man of Her Own',
#  'tt0041699': 'Nora inu',
#  'tt0041716': 'On the Town',
#  'tt0041719': 'Orphée',
#  'tt0041735': 'The Passionate Friends',
#  'tt0041737': 'Passport to Pimlico',
#  'tt0041746': 'Pinky',
#  'tt0041767': 'Prince of Foxes',
#  'tt0041776': 'The Queen of Spades',
#  'tt0041786': 'The Reckless Moment',
#  'tt0041796': 'Reign of Terror',
#  'tt0041822': 'Rope of Sand',
#  'tt0041838': 'Samson and Delilah',
#  'tt0041841': 'Sands of Iwo Jima',
#  'tt0041847': 'Scene of the Crime',
#  'tt0041855': 'The Secret Garden',
#  'tt0041859': 'The Set-Up',
#  'tt0041866': 'She Wore a Yellow Ribbon',
#  'tt0041870': 'Shizukanaru kettô',
#  'tt0041871': 'Shockproof',
#  'tt0041886': 'The Small Back Room',
#  'tt0041890': 'So Dear to My Heart',
#  'tt0041928': 'The Stratton Story',
#  'tt0041931': 'Stromboli (Terra di Dio)',
#  'tt0041944': 'Take Me Out to the Ball Game',
#  'tt0041954': 'Tension',
#  'tt0041955': 'That Forsyte Woman',
#  'tt0041958': "Thieves' Highway",
#  'tt0041959': 'The Third Man',
#  'tt0041967': 'Tokyo Joe',
#  'tt0041968': 'Too Late for Tears',
#  'tt0041994': 'Tulsa',
#  'tt0041996': "Twelve O'Clock High",
#  'tt0042004': 'Under Capricorn',
#  'tt0042039': 'Whirlpool',
#  'tt0042040': 'Whisky Galore!',
#  'tt0042041': 'White Heat',
#  'tt0042046': 'The Window',
#  'tt0042053': "A Woman's Secret",
#  'tt0042176': '711 Ocean Drive',
#  'tt0042179': 'Abbott and Costello in the Foreign Legion',
#  'tt0042192': 'All About Eve',
#  'tt0042200': 'Annie Get Your Gun',
#  'tt0042206': 'Armored Car Robbery',
#  'tt0042208': 'The Asphalt Jungle',
#  'tt0042209': 'At War with the Army',
#  'tt0042210': 'Atoll K',
#  'tt0042219': 'Backfire',
#  'tt0042229': 'The Baron of Arizona',
#  'tt0042235': 'La beauté du diable',
#  'tt0042249': 'The Big Lift',
#  'tt0042256': 'The Black Rose',
#  'tt0042265': 'The Blue Lamp',
#  'tt0042274': 'Borderline',
#  'tt0042275': 'Born to Be Bad',
#  'tt0042276': 'Born Yesterday',
#  'tt0042281': 'The Breaking Point',
#  'tt0042285': 'Bright Leaf',
#  'tt0042296': 'Caged',
#  'tt0042327': 'Cheaper by the Dozen',
#  'tt0042332': 'Cinderella',
#  'tt0042352': 'Crisis',
#  'tt0042355': 'Cronaca di un amore',
#  'tt0042367': 'Cyrano de Bergerac',
#  'tt0042369': 'D.O.A.',
#  'tt0042372': 'Dallas',
#  'tt0042376': "The Damned Don't Cry",
#  'tt0042379': 'Dark City',
#  'tt0042393': 'Destination Moon',
#  'tt0042395': "Devil's Doorway",
#  'tt0042436': 'Les enfants terribles',
#  'tt0042447': 'Fancy Pants',
#  'tt0042451': 'Father of the Bride',
#  'tt0042464': 'The Flame and the Arrow',
#  'tt0042477': 'Francesco, giullare di Dio',
#  'tt0042490': 'The Furies',
#  'tt0042513': 'Gone to Earth',
#  'tt0042530': 'Gun Crazy',
#  'tt0042531': 'The Gunfighter',
#  'tt0042539': 'Halls of Montezuma',
#  'tt0042541': 'The Happiest Days of Your Life',
#  'tt0042544': 'Harriet Craig',
#  'tt0042546': 'Harvey',
#  'tt0042579': 'House by the River',
#  'tt0042593': 'In a Lonely Place',
#  'tt0042609': 'The Jackie Robinson Story',
#  'tt0042619': "Journal d'un curé de campagne",
#  'tt0042643': 'The Killer That Stalked New York',
#  'tt0042644': 'Kim',
#  'tt0042646': "King Solomon's Mines",
#  'tt0042648': 'Kiss Tomorrow Goodbye',
#  'tt0042665': 'Last Holiday',
#  'tt0042692': 'Luci del varietà',
#  'tt0042700': 'Madeleine',
#  'tt0042707': 'The Man Who Cheated Himself',
#  'tt0042727': 'The Men',
#  'tt0042742': 'Mister 880',
#  'tt0042744': 'Montana',
#  'tt0042771': 'Mystery Street',
#  'tt0042788': 'Night and the City',
#  'tt0042792': 'No Way Out',
#  'tt0042804': 'Los olvidados',
#  'tt0042824': 'Outrage',
#  'tt0042832': 'Panic in the Streets',
#  'tt0042869': 'Quicksand',
#  'tt0042876': 'Rashômon',
#  'tt0042895': 'Rio Grande',
#  'tt0042898': 'The Rocking Horse Winner',
#  'tt0042906': 'La ronde',
#  'tt0042949': 'Seven Days to Noon',
#  'tt0042952': 'Shadow on the Wall',
#  'tt0042958': 'Shûbun',
#  'tt0042960': 'Side Street',
#  'tt0042980': 'So Long at the Fair',
#  'tt0042994': 'Stage Fright',
#  'tt0042998': 'Stars in My Crown',
#  'tt0043012': 'Summer Stock',
#  'tt0043014': 'Sunset Blvd.',
#  'tt0043018': 'Susana',
#  'tt0043030': 'Tea for Two',
#  'tt0043041': 'Three Came Home',
#  'tt0043044': 'Three Little Words',
#  'tt0043048': 'Till glädje',
#  'tt0043067': 'Treasure Island',
#  'tt0043075': 'The Sound of Fury',
#  'tt0043090': 'Union Station',
#  'tt0043117': 'Wagon Master',
#  'tt0043123': 'The West Point Story',
#  'tt0043131': 'Where Danger Lives',
#  'tt0043137': "Winchester '73",
#  'tt0043142': 'Woman on the Run',
#  'tt0043147': 'The Wooden Horse',
#  'tt0043153': 'Young Man with a Horn',
#  'tt0043255': 'Bud Abbott Lou Costello Meet the Invisible Man',
#  'tt0043262': 'Across the Wide Missouri',
#  'tt0043265': 'The African Queen',
#  'tt0043274': 'Alice in Wonderland',
#  'tt0043276': 'Along the Great Divide',
#  'tt0043278': 'An American in Paris',
#  'tt0043286': 'Angels in the Outfield',
#  'tt0043288': 'Anne of the Indies',
#  'tt0043292': 'Appointment with Danger',
#  'tt0043299': 'As Young as You Feel',
#  'tt0043303': "L'auberge rouge",
#  'tt0043306': 'Awaara',
#  'tt0043332': 'Bellissima',
#  'tt0043338': 'Ace in the Hole',
#  'tt0043360': 'Bride of the Gorilla',
#  'tt0043362': 'The Browning Version',
#  'tt0043379': 'Captain Horatio Hornblower R.N.',
#  'tt0043386': "Casque d'or",
#  'tt0043390': 'Cause for Alarm!',
#  'tt0043411': 'Císaruv pekar - Pekaruv císar',
#  'tt0043425': "Comin' Round the Mountain",
#  'tt0043435': 'Cry Danger',
#  'tt0043455': 'David and Bathsheba',
#  'tt0043456': 'The Day the Earth Stood Still',
#  'tt0043459': 'Decision Before Dawn',
#  'tt0043461': 'The Desert Fox: The Story of Rommel',
#  'tt0043465': 'Detective Story',
#  'tt0043469': 'Distant Drums',
#  'tt0043503': 'The Enforcer',
#  'tt0043511': "Europa '51",
#  'tt0043526': "Father's Little Dividend",
#  'tt0043539': 'Five',
#  'tt0043540': 'Fixed Bayonets!',
#  'tt0043547': 'Flying Leathernecks',
#  'tt0043560': 'Fourteen Hours',
#  'tt0043565': 'The Frogmen',
#  'tt0043567': 'Fröken Julie',
#  'tt0043590': 'Go for Broke!',
#  'tt0043599': 'The Great Caruso',
#  'tt0043606': 'Guardie e ladri',
#  'tt0043614': 'Hakuchi',
#  'tt0043625': 'He Ran All the Way',
#  'tt0043643': 'His Kind of Woman',
#  'tt0043660': 'The House on Telegraph Hill',
#  'tt0043686': 'Jeux interdits',
#  'tt0043687': 'Jim Thorpe -- All-American',
#  'tt0043727': 'Laughter in Paradise',
#  'tt0043733': 'The Lemon Drop Kid',
#  'tt0043736': "Let's Make It Legal",
#  'tt0043757': 'Lost Continent',
#  'tt0043759': 'Love Nest',
#  'tt0043766': 'M',
#  'tt0043769': 'The Magic Box',
#  'tt0043778': 'The Man from Planet X',
#  'tt0043781': 'Man in the Saddle',
#  'tt0043792': 'The Mating Season',
#  'tt0043801': 'Meshi',
#  'tt0043809': 'Miracolo a Milano',
#  'tt0043812': 'The Mob',
#  'tt0043827': 'My Favorite Spy',
#  'tt0043859': 'No Highway',
#  'tt0043873': 'Has Anybody Seen My Gal',
#  'tt0043879': 'On Dangerous Ground',
#  'tt0043880': 'On Moonlight Bay',
#  'tt0043885': 'Only the Valiant',
#  'tt0043887': 'Operation Pacific',
#  'tt0043892': 'Oyû-sama',
#  'tt0043899': 'Pandora and the Flying Dutchman',
#  'tt0043910': 'Payment on Demand',
#  'tt0043914': "The People Against O'Hara",
#  'tt0043915': 'People Will Talk',
#  'tt0043918': 'Don Camillo',
#  'tt0043924': 'A Place in the Sun',
#  'tt0043927': 'La poison',
#  'tt0043938': 'The Prowler',
#  'tt0043949': 'Quo Vadis',
#  'tt0043955': 'The Racket',
#  'tt0043959': 'Rawhide',
#  'tt0043961': 'The Red Badge of Courage',
#  'tt0043972': 'The River',
#  'tt0043973': 'Roadblock',
#  'tt0043983': 'Royal Wedding',
#  'tt0043989': 'Sailor Beware',
#  'tt0044000': 'Lo sceicco bianco',
#  'tt0044008': 'Scrooge',
#  'tt0044030': 'Show Boat',
#  'tt0044040': 'Sirocco',
#  'tt0044060': 'Sommarlek',
#  'tt0044072': 'The Steel Helmet',
#  'tt0044075': 'Storm Warning',
#  'tt0044079': 'Strangers on a Train',
#  'tt0044081': 'A Streetcar Named Desire',
#  'tt0044084': 'Subida al cielo',
#  'tt0044091': 'Superman and the Mole-Men',
#  'tt0044103': 'The Tales of Hoffmann',
#  'tt0044105': 'The Tall Target',
#  'tt0044121': 'The Thing from Another World',
#  'tt0044186': 'Vengeance Valley',
#  'tt0044205': 'Westward the Women',
#  'tt0044207': 'When Worlds Collide',
#  'tt0044314': '5 Fingers',
#  'tt0044320': 'Abbott and Costello Meet Captain Kidd',
#  'tt0044324': 'Above and Beyond',
#  'tt0044331': 'Affair in Trinidad',
#  'tt0044333': 'Against All Flags',
#  'tt0044357': 'Angel Face',
#  'tt0044364': "Another Man's Poison",
#  'tt0044370': 'April in Paris',
#  'tt0044386': 'Robinson Crusoe',
#  'tt0044391': 'The Bad and the Beautiful',
#  'tt0044406': 'Bela Lugosi Meets a Brooklyn Gorilla',
#  'tt0044413': 'Bend of the River',
#  'tt0044417': 'Beware, My Lovely',
#  'tt0044418': 'Big Jim McLain',
#  'tt0044419': 'The Big Sky',
#  'tt0044420': 'The Big Trees',
#  'tt0044423': 'The Black Castle',
#  'tt0044426': 'Blackbeard, the Pirate',
#  'tt0044446': 'The Sound Barrier',
#  'tt0044453': 'El bruto',
#  'tt0044480': 'Carbine Williams',
#  'tt0044486': 'Carrie',
#  'tt0044487': "Le carrosse d'or",
#  'tt0044497': 'Genbaku no ko',
#  'tt0044502': 'Clash by Night',
#  'tt0044509': 'Come Back, Little Sheba',
#  'tt0044517': 'The Crimson Pirate',
#  'tt0044518': 'Crin blanc: Le cheval sauvage',
#  'tt0044533': 'Deadline - U.S.A.',
#  'tt0044557': "Don't Bother to Knock",
#  'tt0044573': 'The Duel at Silver Creek',
#  'tt0044602': 'Fanfan la Tulipe',
#  'tt0044672': 'The Greatest Show on Earth',
#  'tt0044683': "Hangman's Knot",
#  'tt0044685': 'Hans Christian Andersen',
#  'tt0044706': 'High Noon',
#  'tt0044741': 'Ikiru',
#  'tt0044744': 'The Importance of Being Earnest',
#  'tt0044750': 'Invasion, U.S.A.',
#  'tt0044760': 'Ivanhoe',
#  'tt0044762': 'Jack and the Beanstalk',
#  'tt0044789': 'Kansas City Confidential',
#  'tt0044811': 'Kvinnors väntan',
#  'tt0044825': 'The Las Vegas Story',
#  'tt0044829': 'The Lavender Hill Mob',
#  'tt0044837': 'Limelight',
#  'tt0044851': 'Lost in Alaska',
#  'tt0044860': 'The Lusty Men',
#  'tt0044863': 'Macao',
#  'tt0044876': 'The Man in the White Suit',
#  'tt0044888': 'The Marrying Kind',
#  'tt0044896': 'The Member of the Wedding',
#  'tt0044903': 'Million Dollar Mermaid',
#  'tt0044916': 'Monkey Business',
#  'tt0044926': 'Moulin Rouge',
#  'tt0044937': 'My Cousin Rachel',
#  'tt0044953': 'The Naked Spur',
#  'tt0044954': 'The Narrow Margin',
#  'tt0044981': "O. Henry's Full House",
#  'tt0044982': 'Ochazuke no aji',
#  'tt0045009': 'Park Row',
#  'tt0045012': 'Pat and Mike',
#  'tt0045029': 'Phone Call from a Stranger',
#  'tt0045034': 'Le plaisir',
#  'tt0045039': 'Plymouth Adventure',
#  'tt0045053': 'The Prisoner of Zenda',
#  'tt0045056': 'The Card',
#  'tt0045061': 'The Quiet Man',
#  'tt0045070': 'Rancho Notorious',
#  'tt0045073': 'Red Planet Mars',
#  'tt0045081': 'Le retour de Don Camillo',
#  'tt0045094': 'Road to Bali',
#  'tt0045102': 'Room for One More',
#  'tt0045109': 'Ruby Gentry',
#  'tt0045112': 'Saikaku ichidai onna',
#  'tt0045124': 'Scandal Sheet',
#  'tt0045125': 'Scaramouche',
#  'tt0045152': "Singin' in the Rain",
#  'tt0045161': 'The Sniper',
#  'tt0045162': 'The Snows of Kilimanjaro',
#  'tt0045184': 'Springfield Rifle',
#  'tt0045186': 'The Star',
#  'tt0045192': 'The Stooge',
#  'tt0045197': 'The Story of Robin Hood and His Merrie Men',
#  'tt0045205': 'Sudden Fear',
#  'tt0045274': 'Umberto D.',
#  'tt0045283': 'Valkoinen peura',
#  'tt0045296': 'Viva Zapata!',
#  'tt0045317': "We're Not Married!",
#  'tt0045323': 'What Price Glory',
#  'tt0045333': 'With a Song in My Heart',
#  'tt0045339': 'The World in His Arms',
#  'tt0045361': 'Él',
#  'tt0045464': 'The 5,000 Fingers of Dr. T.',
#  'tt0045465': '99 River Street',
#  'tt0045468': 'Abbott and Costello Go to Mars',
#  'tt0045469': 'Abbott and Costello Meet Dr. Jekyll and Mr. Hyde',
#  'tt0045471': 'The Actress',
#  'tt0045492': 'All I Desire',
#  'tt0045518': 'Arrowhead',
#  'tt0045537': 'The Band Wagon',
#  'tt0045544': 'Battle Circus',
#  'tt0045546': 'The Beast from 20,000 Fathoms',
#  'tt0045551': 'Beneath the 12-Mile Reef',
#  'tt0045554': 'Bienvenido Mister Marshall',
#  'tt0045555': 'The Big Heat',
#  'tt0045557': 'The Bigamist',
#  'tt0045564': 'The Blue Gardenia',
#  'tt0045566': 'A Blueprint for Murder',
#  'tt0045586': 'By the Light of the Silvery Moon',
#  'tt0045589': 'The Caddy',
#  'tt0045591': 'Calamity Jane',
#  'tt0045592': 'Call Me Madam',
#  'tt0045607': "The Captain's Paradise",
#  'tt0045609': 'Cat-Women of the Moon',
#  'tt0045631': 'City That Never Sleeps',
#  'tt0045659': 'The Cruel Sea',
#  'tt0045669': 'Dangerous Crossing',
#  'tt0045679': 'The Desert Rats',
#  'tt0045693': 'Do Bigha Zamin',
#  'tt0045699': "Donovan's Brain",
#  'tt0045706': 'Dream Wife',
#  'tt0045737': 'Escape from Fort Bravo',
#  'tt0045758': 'Fear and Desire',
#  'tt0045793': 'From Here to Eternity',
#  'tt0045808': 'Genevieve',
#  'tt0045810': 'Gentlemen Prefer Blondes',
#  'tt0045814': 'Gion bayashi',
#  'tt0045826': 'Glen or Glenda',
#  'tt0045846': 'Gun Fury',
#  'tt0045848': 'Gycklarnas afton',
#  'tt0045876': "His Majesty O'Keefe",
#  'tt0045883': 'Hondo',
#  'tt0045886': 'Houdini',
#  'tt0045888': 'House of Wax',
#  'tt0045891': 'How to Marry a Millionaire',
#  'tt0045897': 'I Confess',
#  'tt0045907': 'La ilusión viaja en tranvía',
#  'tt0045911': 'Inferno',
#  'tt0045919': 'Island in the Sky',
#  'tt0045920': 'It Came from Outer Space',
#  'tt0045932': 'Jeopardy',
#  'tt0045935': 'Jigokumon',
#  'tt0045943': 'Julius Caesar',
#  'tt0045963': 'Kiss Me Kate',
#  'tt0045966': 'Knights of the Round Table',
#  'tt0045992': 'The Lawless Breed',
#  'tt0046000': 'Lili',
#  'tt0046004': 'Little Fugitive',
#  'tt0046022': 'Madame de...',
#  'tt0046026': 'The Magnetic Monster',
#  'tt0046029': 'Malta Story',
#  'tt0046031': 'The Man Between',
#  'tt0046035': 'The Man from the Alamo',
#  'tt0046040': 'Man on a Tightrope',
#  'tt0046054': 'The Master of Ballantrae',
#  'tt0046066': 'Mesa of Lost Women',
#  'tt0046072': 'The Million Pound Note',
#  'tt0046076': 'Miss Sadie Thompson',
#  'tt0046126': 'Niagara',
#  'tt0046159': 'Pane, amore e fantasia',
#  'tt0046183': 'Peter Pan',
#  'tt0046186': 'Phantom from Space',
#  'tt0046187': 'Pickup on South Street',
#  'tt0046198': 'Pony Express',
#  'tt0046247': 'The Robe',
#  'tt0046248': 'Robot Monster',
#  'tt0046250': 'Roman Holiday',
#  'tt0046268': 'Le salaire de la peur',
#  'tt0046269': 'Salome',
#  'tt0046280': 'Scared Stiff',
#  'tt0046303': 'Shane',
#  'tt0046313': 'La signora senza camelie',
#  'tt0046345': 'Sommaren med Monika',
#  'tt0046353': 'Split Second',
#  'tt0046359': 'Stalag 17',
#  'tt0046366': 'Stazione Termini',
#  'tt0046374': 'The Story of Three Loves',
#  'tt0046384': 'The Sun Shines Bright',
#  'tt0046414': 'Beat the Devil',
#  'tt0046425': 'Thunder Bay',
#  'tt0046429': 'Thérèse Raquin',
#  'tt0046435': 'Titanic',
#  'tt0046436': 'The Titfield Thunderbolt',
#  'tt0046438': 'Tôkyô monogatari',
#  'tt0046446': 'Torch Song',
#  'tt0046451': 'Touchez pas au grisbi',
#  'tt0046463': 'Trouble Along the Way',
#  'tt0046478': 'Ugetsu monogatari',
#  'tt0046487': 'Les vacances de Monsieur Hulot',
#  'tt0046511': 'Viaggio in Italia',
#  'tt0046521': 'I vitelloni',
#  'tt0046534': 'The War of the Worlds',
#  'tt0046564': 'Young Bess',
#  'tt0046672': '20,000 Leagues Under the Sea',
#  'tt0046675': 'Abismos de pasión',
#  'tt0046705': 'Un americano a Roma',
#  'tt0046719': 'Apache',
#  'tt0046754': 'The Barefoot Contessa',
#  'tt0046759': 'Beau Brummell',
#  'tt0046766': "The Belles of St. Trinian's",
#  'tt0046770': 'Betrayed',
#  'tt0046789': 'The Black Shield of Falworth',
#  'tt0046791': 'Black Widow',
#  'tt0046806': 'The Bridges at Toko-Ri',
#  'tt0046808': 'Broken Lance',
#  'tt0046816': 'The Caine Mutiny',
#  'tt0046828': 'Carmen Jones',
#  'tt0046851': 'Chikamatsu monogatari',
#  'tt0046874': 'The Country Girl',
#  'tt0046876': 'Creature from the Black Lagoon',
#  'tt0046878': 'Crime Wave',
#  'tt0046889': 'The Dam Busters',
#  'tt0046899': 'Demetrius and the Gladiators',
#  'tt0046903': 'Désirée',
#  'tt0046906': 'Destry',
#  'tt0046907': 'Devil Girl from Mars',
#  'tt0046911': 'Les diaboliques',
#  'tt0046912': 'Dial M for Murder',
#  'tt0046921': 'Doctor in the House',
#  'tt0046935': 'Drive a Crooked Road',
#  'tt0046949': 'The Egyptian',
#  'tt0046951': 'Elephant Walk',
#  'tt0046963': 'Executive Suite',
#  'tt0046969': 'The Fast and the Furious',
#  'tt0046970': 'Father Brown',
#  'tt0046977': 'Fire Maidens from Outer Space',
#  'tt0046998': 'French Cancan',
#  'tt0047013': 'Garden of Evil',
#  'tt0047030': 'The Glenn Miller Story',
#  'tt0047033': 'Gog',
#  'tt0047034': 'Gojira',
#  'tt0047050': 'Green Fire',
#  'tt0047073': 'Hell and High Water',
#  'tt0047085': "The 'Maggie'",
#  'tt0047086': 'The High and the Mighty',
#  'tt0047094': "Hobson's Choice",
#  'tt0047101': 'Human Desire',
#  'tt0047119': 'An Inspector Calls',
#  'tt0047123': 'It Should Happen to You',
#  'tt0047127': 'Jail Bait',
#  'tt0047136': 'Johnny Guitar',
#  'tt0047149': 'Killers from Space',
#  'tt0047162': 'The Last Time I Saw Paris',
#  'tt0047167': 'En lektion i kärlek',
#  'tt0047184': 'Living It Up',
#  'tt0047191': 'The Long, Long Trailer',
#  'tt0047200': 'The Mad Magician',
#  'tt0047203': 'Magnificent Obsession',
#  'tt0047209': 'Man in the Attic',
#  'tt0047238': 'Miseria e nobiltà',
#  'tt0047264': 'The Naked Jungle',
#  'tt0047279': 'Night People',
#  'tt0047281': 'Nijûshi no hitomi',
#  'tt0047296': 'On the Waterfront',
#  'tt0047313': "L'oro di Napoli",
#  'tt0047336': "Non credo più all'amore (La paura)",
#  'tt0047349': 'Phffft',
#  'tt0047365': 'Prince Valiant',
#  'tt0047370': 'Private Hell 36',
#  'tt0047376': 'The Purple Plain',
#  'tt0047377': 'Pushover',
#  'tt0047396': 'Rear Window',
#  'tt0047417': 'Riot in Cell Block 11',
#  'tt0047422': 'River of No Return',
#  'tt0047437': 'Sabrina',
#  'tt0047443': 'Salt of the Earth',
#  'tt0047445': 'Sanshô dayû',
#  'tt0047464': 'Secret of the Incas',
#  'tt0047469': 'Senso',
#  'tt0047472': 'Seven Brides for Seven Brothers',
#  'tt0047478': 'Shichinin no samurai',
#  'tt0047479': 'Shield for Murder',
#  'tt0047494': 'The Silver Chalice',
#  'tt0047495': 'Silver Lode',
#  'tt0047522': 'A Star Is Born',
#  'tt0047528': 'La strada',
#  'tt0047542': 'Suddenly',
#  'tt0047550': 'Susan Slept Here',
#  'tt0047559': 'Target Earth',
#  'tt0047572': 'Des Teufels General',
#  'tt0047573': 'Them!',
#  'tt0047574': "There's No Business Like Show Business",
#  'tt0047577': 'This Island Earth',
#  'tt0047580': 'Three Coins in the Fountain',
#  'tt0047603': 'Track of the Cat',
#  'tt0047630': 'Ulisse',
#  'tt0047641': 'Valley of the Kings',
#  'tt0047647': 'Vera Cruz',
#  'tt0047673': 'White Christmas',
#  'tt0047677': 'The Wild One',
#  'tt0047679': 'Witness to Murder',
#  'tt0047682': 'Yama no oto',
#  'tt0047688': 'Young at Heart',
#  'tt0047795': 'Abbott and Costello Meet the Mummy',
#  'tt0047797': 'Above Us the Waves',
#  'tt0047811': 'All That Heaven Allows',
#  'tt0047821': 'Le amiche',
#  'tt0047834': 'Animal Farm',
#  'tt0047840': 'Artists and Models',
#  'tt0047849': 'Bad Day at Black Rock',
#  'tt0047860': 'Battle Cry',
#  'tt0047873': 'The Benny Goodman Story',
#  'tt0047876': 'Il bidone',
#  'tt0047878': 'The Big Combo',
#  'tt0047880': 'The Big Knife',
#  'tt0047885': 'Blackboard Jungle',
#  'tt0047889': 'Blood Alley',
#  'tt0047892': 'Bob le flambeur',
#  'tt0047898': 'Bride of the Monster',
#  'tt0047930': 'Cesta do praveku',
#  'tt0047944': 'The Cobweb',
#  'tt0047945': 'The Colditz Story',
#  'tt0047947': 'Conquest of Space',
#  'tt0047956': 'The Court-Martial of Billy Mitchell',
#  'tt0047960': 'Creature with the Atom Brain',
#  'tt0047969': 'Daddy Long Legs',
#  'tt0047976': 'Dementia',
#  'tt0047977': 'Davy Crockett: King of the Wild Frontier',
#  'tt0047985': 'The Desperate Hours',
#  'tt0047990': 'Devdas',
#  'tt0048002': "Don Camillo e l'on. Peppone",
#  'tt0048021': 'Du rififi chez les hommes',
#  'tt0048028': 'East of Eden',
#  'tt0048034': 'The End of the Affair',
#  'tt0048037': 'Ensayo de un crimen',
#  'tt0048055': 'The Far Country',
#  'tt0048064': 'Female on the Beach',
#  'tt0048077': '5 Against the House',
#  'tt0048087': 'Footsteps in the Fog',
#  'tt0048124': 'The Glass Slipper',
#  'tt0048127': 'Gojira no gyakushû',
#  'tt0048140': 'Guys and Dolls',
#  'tt0048182': 'House of Bamboo',
#  'tt0048191': "I'll Cry Tomorrow",
#  'tt0048198': 'Ikimono no kiroku',
#  'tt0048199': 'Illegal',
#  'tt0048204': 'The Indian Fighter',
#  'tt0048215': 'It Came from Beneath the Sea',
#  'tt0048216': "It's Always Fair Weather",
#  'tt0048233': 'Jubal',
#  'tt0048248': 'The Kentuckian',
#  'tt0048254': "Killer's Kiss",
#  'tt0048256': 'King Dinosaur',
#  'tt0048260': 'Kismet',
#  'tt0048261': 'Kiss Me Deadly',
#  'tt0048272': 'Kvinnodröm',
#  'tt0048275': 'Körhinta',
#  'tt0048280': 'Lady and the Tramp',
#  'tt0048281': 'The Ladykillers',
#  'tt0048283': 'Land of the Pharaohs',
#  'tt0048289': 'A Lawless Street',
#  'tt0048291': 'The Left Hand of God',
#  'tt0048308': 'Lola Montès',
#  'tt0048312': 'The Long Gray Line',
#  'tt0048316': 'Love Is a Many-Splendored Thing',
#  'tt0048317': 'Love Me or Leave Me',
#  'tt0048339': 'Man with the Gun',
#  'tt0048340': 'Man Without a Star',
#  'tt0048342': 'The Man from Laramie',
#  'tt0048347': 'The Man with the Golden Arm',
#  'tt0048356': 'Marty',
#  'tt0048380': 'Mister Roberts',
#  'tt0048387': 'Moonfleet',
#  'tt0048394': 'Muerte de un ciclista',
#  'tt0048401': 'My Sister Eileen',
#  'tt0048424': 'The Night of the Hunter',
#  'tt0048432': 'Not as a Stranger',
#  'tt0048445': 'Oklahoma!',
#  'tt0048452': 'Ordet',
#  'tt0048473': 'Pather Panchali',
#  'tt0048484': "Pete Kelly's Blues",
#  'tt0048488': 'The Phenix City Story',
#  'tt0048491': 'Picnic',
#  'tt0048499': 'La Pointe-Courte',
#  'tt0048500': 'Pokolenie',
#  'tt0048527': 'Queen Bee',
#  'tt0048543': 'Razzia sur la chnouf',
#  'tt0048545': 'Rebel Without a Cause',
#  'tt0048554': 'Revenge of the Creature',
#  'tt0048563': 'The Rose Tattoo',
#  'tt0048570': 'Run for Cover',
#  'tt0048579': 'Zoku Miyamoto Musashi: Ichijôji no kettô',
#  ...}
