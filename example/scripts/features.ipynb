# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Features

# %%
import matplotlib.pyplot as plt

from movie_ratings import config
from taskchain import Config

# %%
config_name = 'features/all.yaml'
chain = Config(config.TASKS_DIR, config.CONFIGS_DIR / config_name, global_vars=config).chain()
chain
# Out:
# <chain for config `all`>

# %%
chain.draw()

# %% [markdown]
# ## Directors

# %%
len(chain.directors.value)
# Out:
# 12263

# %%
len(chain.selected_directors.value)
# Out:
# Reading from /home/thran/projects/taskchain/example/data/task_data/features/selected_directors/cb5640b8366b92b…
# 411

# %% [markdown]
# ## Actors

# %%
len(chain.actors.value)
# Out:
# 173183

# %%
len(chain.selected_actors.value)
# Out:
# 1713

# %% [markdown]
# ## Features

# %%
len(chain.feature_names.value)
# Out:
# 2029

# %%
chain.feature_names.value[:30]
# Out:
# ['year',
#  'duration',
#  'genre_Action',
#  'genre_Adult',
#  'genre_Adventure',
#  'genre_Animation',
#  'genre_Biography',
#  'genre_Comedy',
#  'genre_Crime',
#  'genre_Documentary',
#  'genre_Drama',
#  'genre_Family',
#  'genre_Fantasy',
#  'genre_Film-Noir',
#  'genre_History',
#  'genre_Horror',
#  'genre_Music',
#  'genre_Musical',
#  'genre_Mystery',
#  'genre_Romance',
#  'genre_Sci-Fi',
#  'genre_Sport',
#  'genre_Thriller',
#  'genre_War',
#  'genre_Western',
#  'country_Afghanistan',
#  'country_Albania',
#  'country_Algeria',
#  'country_Angola',
#  'country_Argentina']

# %%
chain.features.value.shape
# Out:
# (28215, 2029)
